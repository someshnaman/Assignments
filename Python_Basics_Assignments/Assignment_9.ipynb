# %% [markdown]
# 1. To what does a relative path refer?

# %% [markdown]
# Ans - A relative path refers to the path  relative to location that is relative to your current directory. This relative path can be lead by . and .. Wheere . represents present directory and .. represent parent directory. Let's take and Ex.
# ![image.png](attachment:image.png)
#
# Suppose this is your herrarichy of DIRECTORY. let's consider your are in D:\Data\Shapefiles\Soils and you want to navigate to the Landuse directory from the current directory (Soils) you could type the following in the Windows Explorer Address box:
#
# ### ..\Landuse

# %% [markdown]
# 2. What does an absolute path start with your operating system?

# %% [markdown]
# Ans - it start with the Drive name in our Operating ssytem and lead to exactly the file where it present folder by folder. Ex .
# If you look into the above question there is the folder soils which is present in the D drive so the abosolute path would
# be **D:\Data\Shapefiles\Soils**

# %% [markdown]
# 3. What do the functions os.getcwd() and os.chdir() do?

# %% [markdown]
# Ans - os.getwed() will give you present working directory whereas os.chdir() will change the current working directory to the
# directory passed in the argument

# %% [markdown]
# 4. What are the . and .. folders?

# %% [markdown]
# Ans - this is the notation of navigating to files present in current working directory and parent directory.
# ./ is used for navigating to the files present in current working directory and ../is used to lead to parent directory.

# %% [markdown]
# 5. In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?

# %% [markdown]
# Ans - This is C:\bacon\eggs\ and spam.txt is the base or we can say  file name.

# %% [markdown]
# 6. What are the three “mode” arguments that can be passed to the open() function?

# %% [markdown]
# Ans - there are several modes are available in mode arguments some are
#
# 'r'       open for reading (default)
#
# 'w'       open for writing, truncating the file first
#
# 'x'       create a new file and open it for writing
#
# 'a'       open for writing, appending to the end of the file if it exists
#
# 'b'       binary mode
#
# 't'       text mode (default)
#
# '+'       open a disk file for updating (reading and writing)
#
# 'U'       universal newline mode (deprecated)

# %% [markdown]
# 7. What happens if an existing file is opened in write mode?

# %% [markdown]
# Ans - The file will be open for writing if not excist and if exist it will truncate all the material inside it and set the cursor at 0 index.

# %% [markdown]
# 8. How do you tell the difference between read() and readlines()?

# %% [markdown]
# Ans - read() will try to read all the content inside it whereas realines() function will read line by line into the content.

# %% [markdown]
# 9. What data structure does a shelf value resemble?

# %%
We can say it's a kind of dictionary means when you have to find some books you look for key and go there
