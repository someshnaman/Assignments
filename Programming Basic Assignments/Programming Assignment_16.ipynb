# %% [markdown]
# Question1. Write a function that stutters a word as if someone is struggling to read it. The
# first two letters are repeated twice with an ellipsis ... and space after each, and then the
# word is pronounced with a question mark ?.
#
# Examples
#
# stutter(&quot;incredible&quot;) ➞ &quot;in... in... incredible?&quot;
#
# stutter(&quot;enthusiastic&quot;) ➞ &quot;en... en... enthusiastic?&quot;
#
# stutter(&quot;outstanding&quot;) ➞ &quot;ou... ou... outstanding?&quot;
#
# Hint :- Assume all input is in lower case and at least two characters long.

# %%
class word:
    try:
        def stutters(self,l):            
            print(l[0:2]+'...'+l[0:2]+'...'+l+'?')
    except Exception as e:
        print(e)

# %%
myu=word()
myu.stutters('incredible')
# Out:
# in...in...incredible?

# %% [markdown]
# Question 2.Create a function that takes an angle in radians and returns the corresponding
# angle in degrees rounded to one decimal place.
# Examples
# radians_to_degrees(1) ➞ 57.3
# radians_to_degrees(20) ➞ 1145.9
# radians_to_degrees(50) ➞ 2864.8

# %%
class angle:
    def degToRad(self):
        user_input=float(input("Please enter the angle you would like to change in degree:\n").strip())
        formulaa=57.29*user_input
        
        return f"Total angle is {round(formulaa,1)}"

# %%
ang=angle()
ang.degToRad()
# Out:
# Please enter the angle you would like to change in degree:
# 50
# 'Total angle is 2864.5'

# %% [markdown]
# Question 3. In this challenge, establish if a given integer num is a Curzon number. If 1 plus
# 2 elevated to num is exactly divisible by 1 plus 2 multiplied by num, then num is a Curzon
# number.
# Given a non-negative integer num, implement a function that returns True if num is a Curzon
# number, or False otherwise.
# Examples
# is_curzon(5) ➞ True
# # 2 ** 5 + 1 = 33
# # 2 * 5 + 1 = 11
# # 33 is a multiple of 11
# is_curzon(10) ➞ False
# # 2 ** 10 + 1 = 1025
# # 2 * 10 + 1 = 21
# # 1025 is not a multiple of 21
# is_curzon(14) ➞ True
# # 2 ** 14 + 1 = 16385
# # 2 * 14 + 1 = 29
# # 16385 is a multiple of 29

# %%
class number:
    def  curzon_number(self,n):
        x=(2**n+1)
        y=(2*n+1)
                
        if x % y ==0:
            return f"{n} is a  Curzon number"
        else:
            return f"{n} is not a  Curzon number"

# %%
num=number()
num.curzon_number(5)
# Out:
# '5 is a  Curzon number'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
def area(n):
    A=round(((3 * math.sqrt(3))/2)* n**2,1)
    return f"The area of Hexagan is {A} mitre square"

# %%
area(1)
# Out:
# 'The area of Hexagan is 2.6 mitre square'

# %% [markdown]
# Question 5. Create a function that returns a base-2 (binary) representation of a base-10
# (decimal) string number. To convert is simple: ((2) means base-2 and (10) means base-10)
# 010101001(2) = 1 + 8 + 32 + 128.
# Going from right to left, the value of the most right bit is 1, now from that every bit to the left
# will be x2 the value, value of an 8 bit binary numbers are (256, 128, 64, 32, 16, 8, 4, 2, 1).
# Examples
# binary(1) ➞ &quot;1&quot;
# # 1*1 = 1
# binary(5) ➞ &quot;101&quot;
# # 1*1 + 1*4 = 5
# binary(10) ➞ &quot;1010&quot;
# # 1*2 + 1*8 = 10

# %%
def binary(n):
    # the given is is in base 10
    list1=[]
    number=[]
    i=2
    j=0
    while i<n:
        i=2**j
        list1.append(i)
        j+=1
    list1=list(reversed(list1))
    for i in list1:        
        if i>n:
            list1.remove(i)    
    j=0    
    while j<len(list1):
        if list1[j]==n:
            number.append(1)
            j+=1        
        
        elif list1[j]<n:
            n=n-list1[j]
            number.append(1)
            j+=1                          
        else:
            number.append(0)
            j+=1
            
    result="".join([str(i) for i in number])
    return f"Here is our Final Result {result}"

# %%
binary(89)
# Out:
# 'Here is our Final Result 1011001'
